# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt

all_data = loadmat('data/data_flight16.mat')
act_data = loadmat('data/actos_flight16.mat')

# %%
plt.plot(act_data['licorH2O'])
plt.show()

# %%
plt.plot(act_data['sonicTV'])
plt.show()

# %%
plt.plot(act_data['dp1AH'])
plt.show()

# %%
plt.plot(act_data['sonicPRT'])
plt.show()

# %%
plt.plot(act_data['hmpT'] - act_data['sonicPRT'])
plt.show()

# %%
all_data['licorH2O']
# Out:
# array([[ 11.35024032],
#        [ 11.33663851],
#        [ 11.32214284],
#        ...,
#        [ 10.68581795],
#        [ 10.67132548],
#        [ 10.66666138]])
